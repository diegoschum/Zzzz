# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error



from sklearn.feature_selection import RFE
import statsmodels.formula.api as smf

# %%
#import cleaned
df = pd.read_csv('cleaned_data.csv')

# %%
df.corr()["cast_total_facebook_likes"]
# Out:
# duration                     0.120210
# director_facebook_likes      0.118573
# actor_3_facebook_likes       0.489800
# actor_1_facebook_likes       0.944816
# gross                        0.235669
# cast_total_facebook_likes    1.000000
# facenumber_in_poster         0.080765
# budget                       0.028703
# title_year                   0.126927
# actor_2_facebook_likes       0.643003
# aspect_ratio                 0.068860
# profit                       0.043866
# gross_bin                    0.203394
# action                       0.059598
# adventure                    0.068826
# animation                   -0.003097
# biography                    0.020964
# comedy                      -0.057746
# crime                        0.027423
# documentary                 -0.060534
# drama                        0.001105
# family                       0.001051
# fantasy                      0.040610
# film-noir                   -0.008936
# history                     -0.017975
# horror                      -0.066516
# music                       -0.049855
# musical                     -0.036820
# mystery                     -0.003012
# romance                     -0.021341
# sci_fi                       0.019890
# sport                       -0.014426
# thriller                     0.032503
# war                         -0.007026
# western                      0.018054
# director_high                0.073412
# director_low                -0.073412
# actor_1_high                 0.201102
# actor_1_low                 -0.201102
# actor_2_high                 0.126513
# actor_2_low                 -0.126513
# actor_3_high                 0.042991
# actor_3_low                 -0.042991
# is_english                   0.105589
# profit_binary                0.047983
# Name: cast_total_facebook_likes, dtype: float64

# %% [markdown]
# We can see from above that facebook likes is extremely correlated with the number of facebook likes of actor 1 (0.932273), as well as actor 2 (0.706831), and actor 3(0.551871). This should be taken into account when making the model (interactions).

# %% [markdown]
# ## Which combination of actors are most profitable?

# %%
df_people = df[["director_name", "director_facebook_likes",  "actor_1_name", "actor_1_facebook_likes","actor_2_name", "actor_2_facebook_likes", "actor_3_name","actor_3_facebook_likes", "cast_total_facebook_likes",  "profit"]]

# %%
yay = df_people.groupby(["director_name","actor_1_name", "actor_2_name", "actor_3_name"])[["profit"]].agg("mean").sort_values(by = "profit", ascending=False)
yay
# Out:
#                                                                               profit
# director_name    actor_1_name        actor_2_name       actor_3_name
# James Cameron    CCH Pounder         Joel David Moore   Wes Studi       5.235058e+08
# Colin Trevorrow  Bryce Dallas Howard Judy Greer         Omar Sy         5.021773e+08
# James Cameron    Leonardo DiCaprio   Kate Winslet       Gloria Stuart   4.586723e+08
# George Lucas     Harrison Ford       Peter Cushing      Kenny Baker     4.499357e+08
# Steven Spielberg Henry Thomas        Dee Wallace        Peter Coyote    4.244495e+08
# ...                                                                              ...
# Katsuhiro Ôtomo  William Hootkins    Robin Atkin Downes Rosalind Ayres -2.127110e+09
# Hayao Miyazaki   Minnie Driver       Jada Pinkett Smith Billy Crudup   -2.397702e+09
# Lajos Koltai     Marcell Nagy        Péter Fancsikai    Bálint Péntek  -2.499804e+09
# Chan-wook Park   Min-sik Choi        Yeong-ae Lee       Hye-jeong Kang -4.199788e+09
# Joon-ho Bong     Doona Bae           Kang-ho Song       Ah-sung Ko     -1.221330e+10
#
# [3642 rows x 1 columns]

# %%
yay[:3]
# Out:
#                                                                          profit
# director_name   actor_1_name        actor_2_name     actor_3_name
# James Cameron   CCH Pounder         Joel David Moore Wes Studi      523505847.0
# Colin Trevorrow Bryce Dallas Howard Judy Greer       Omar Sy        502177271.0
# James Cameron   Leonardo DiCaprio   Kate Winslet     Gloria Stuart  458672302.0

# %%
df_people.groupby(["director_name","actor_1_name", "actor_2_name", "actor_3_name"]).agg("count")
# Out:
#                                                                         director_facebook_likes  \
# director_name      actor_1_name        actor_2_name      actor_3_name
# Aaron Schneider    Bill Murray         Robert Duvall     Bill Cobbs                           1
# Aaron Seltzer      Alyson Hannigan     Carmen Electra    Fred Willard                         1
# Abel Ferrara       Isabella Rossellini Vincent Gallo     Gretchen Mol                         1
# Adam Goldberg      Judy Greer          Marisa Coughlan   Nicky Katt                           1
# Adam Marcus        Kane Hodder         Leslie Jordan     Erin Gray                            1
# ...                                                                                         ...
# Zack Snyder        Ty Burrell          Kevin Zegers      Mekhi Phifer                         2
# Zak Penn           Zak Penn            Gabriel Beristain John Bailey                          1
# Zal Batmanglij     Alexander Skarsgård Julia Ormond      Jason Ritter                         1
# Álex de la Iglesia Jim Carter          Leonor Watling    Danny Sapani                         1
# Émile Gaudreault   Paul Sorvino        Luke Kirby        Claudia Ferri                        1
#
#                                                                         actor_1_facebook_likes  \
# director_name      actor_1_name        actor_2_name      actor_3_name
# Aaron Schneider    Bill Murray         Robert Duvall     Bill Cobbs                          1
# Aaron Seltzer      Alyson Hannigan     Carmen Electra    Fred Willard                        1
# Abel Ferrara       Isabella Rossellini Vincent Gallo     Gretchen Mol                        1
# Adam Goldberg      Judy Greer          Marisa Coughlan   Nicky Katt                          1
# Adam Marcus        Kane Hodder         Leslie Jordan     Erin Gray                           1
# ...                                                                                        ...
# Zack Snyder        Ty Burrell          Kevin Zegers      Mekhi Phifer                        2
# Zak Penn           Zak Penn            Gabriel Beristain John Bailey                         1
# Zal Batmanglij     Alexander Skarsgård Julia Ormond      Jason Ritter                        1
# Álex de la Iglesia Jim Carter          Leonor Watling    Danny Sapani                        1
# Émile Gaudreault   Paul Sorvino        Luke Kirby        Claudia Ferri                       1
#
#                                                                         actor_2_facebook_likes  \
# director_name      actor_1_name        actor_2_name      actor_3_name
# Aaron Schneider    Bill Murray         Robert Duvall     Bill Cobbs                          1
# Aaron Seltzer      Alyson Hannigan     Carmen Electra    Fred Willard                        1
# Abel Ferrara       Isabella Rossellini Vincent Gallo     Gretchen Mol                        1
# Adam Goldberg      Judy Greer          Marisa Coughlan   Nicky Katt                          1
# Adam Marcus        Kane Hodder         Leslie Jordan     Erin Gray                           1
# ...                                                                                        ...
# Zack Snyder        Ty Burrell          Kevin Zegers      Mekhi Phifer                        2
# Zak Penn           Zak Penn            Gabriel Beristain John Bailey                         1
# Zal Batmanglij     Alexander Skarsgård Julia Ormond      Jason Ritter                        1
# Álex de la Iglesia Jim Carter          Leonor Watling    Danny Sapani                        1
# Émile Gaudreault   Paul Sorvino        Luke Kirby        Claudia Ferri                       1
#
#                                                                         actor_3_facebook_likes  \
# director_name      actor_1_name        actor_2_name      actor_3_name
# Aaron Schneider    Bill Murray         Robert Duvall     Bill Cobbs                          1
# Aaron Seltzer      Alyson Hannigan     Carmen Electra    Fred Willard                        1
# Abel Ferrara       Isabella Rossellini Vincent Gallo     Gretchen Mol                        1
# Adam Goldberg      Judy Greer          Marisa Coughlan   Nicky Katt                          1
# Adam Marcus        Kane Hodder         Leslie Jordan     Erin Gray                           1
# ...                                                                                        ...
# Zack Snyder        Ty Burrell          Kevin Zegers      Mekhi Phifer                        2
# Zak Penn           Zak Penn            Gabriel Beristain John Bailey                         1
# Zal Batmanglij     Alexander Skarsgård Julia Ormond      Jason Ritter                        1
# Álex de la Iglesia Jim Carter          Leonor Watling    Danny Sapani                        1
# Émile Gaudreault   Paul Sorvino        Luke Kirby        Claudia Ferri                       1
#
#                                                                         cast_total_facebook_likes  \
# director_name      actor_1_name        actor_2_name      actor_3_name
# Aaron Schneider    Bill Murray         Robert Duvall     Bill Cobbs                             1
# Aaron Seltzer      Alyson Hannigan     Carmen Electra    Fred Willard                           1
# Abel Ferrara       Isabella Rossellini Vincent Gallo     Gretchen Mol                           1
# Adam Goldberg      Judy Greer          Marisa Coughlan   Nicky Katt                             1
# Adam Marcus        Kane Hodder         Leslie Jordan     Erin Gray                              1
# ...                                                                                           ...
# Zack Snyder        Ty Burrell          Kevin Zegers      Mekhi Phifer                           2
# Zak Penn           Zak Penn            Gabriel Beristain John Bailey                            1
# Zal Batmanglij     Alexander Skarsgård Julia Ormond      Jason Ritter                           1
# Álex de la Iglesia Jim Carter          Leonor Watling    Danny Sapani                           1
# Émile Gaudreault   Paul Sorvino        Luke Kirby        Claudia Ferri                          1
#
#                                                                         profit
# director_name      actor_1_name        actor_2_name      actor_3_name
# Aaron Schneider    Bill Murray         Robert Duvall     Bill Cobbs          1
# Aaron Seltzer      Alyson Hannigan     Carmen Electra    Fred Willard        1
# Abel Ferrara       Isabella Rossellini Vincent Gallo     Gretchen Mol        1
# Adam Goldberg      Judy Greer          Marisa Coughlan   Nicky Katt          1
# Adam Marcus        Kane Hodder         Leslie Jordan     Erin Gray           1
# ...                                                                        ...
# Zack Snyder        Ty Burrell          Kevin Zegers      Mekhi Phifer        2
# Zak Penn           Zak Penn            Gabriel Beristain John Bailey         1
# Zal Batmanglij     Alexander Skarsgård Julia Ormond      Jason Ritter        1
# Álex de la Iglesia Jim Carter          Leonor Watling    Danny Sapani        1
# Émile Gaudreault   Paul Sorvino        Luke Kirby        Claudia Ferri       1
#
# [3642 rows x 6 columns]

# %% [markdown]
# Most profitable combination of director and actors is James Cameron, CCH Pounder, Joel David Moore, and Wes Studi.

# %%
director = df_people.groupby(["director_name"])[["profit"]].agg("mean").sort_values(by = "profit", ascending=False).reset_index()
director
# Out:
#          director_name        profit
# 0           Tim Miller  3.050243e+08
# 1         George Lucas  2.773283e+08
# 2     Richard Marquand  2.766254e+08
# 3           Kyle Balda  2.620296e+08
# 4      Colin Trevorrow  2.527175e+08
# ...                ...           ...
# 1654     Takao Okawara -9.899626e+08
# 1655    Chan-wook Park -1.403635e+09
# 1656   Katsuhiro Ôtomo -1.613335e+09
# 1657      Lajos Koltai -2.499804e+09
# 1658      Joon-ho Bong -6.123968e+09
#
# [1659 rows x 2 columns]

# %%
actor_1 = df_people.groupby(["actor_1_name"])[["profit"]].agg("mean").sort_values(by = "profit", ascending=False).reset_index()
actor_1
# Out:
#           actor_1_name        profit
# 0         Wayne Knight  2.937840e+08
# 1       Rupert Everett  2.864710e+08
# 2       Catherine Dyer  2.269504e+08
# 3         Henry Thomas  2.113146e+08
# 4     Kathleen Freeman  2.076520e+08
# ...                ...           ...
# 1423      Mitsuo Iwata -1.099561e+09
# 1424      Min-sik Choi -1.404099e+09
# 1425  William Hootkins -2.127110e+09
# 1426      Marcell Nagy -2.499804e+09
# 1427         Doona Bae -1.221330e+10
#
# [1428 rows x 2 columns]

# %%
actor_2 = df_people.groupby(["actor_2_name"])[["profit"]].agg("mean").sort_values(by = "profit", ascending=False).reset_index()
actor_2
# Out:
#             actor_2_name        profit
# 0          Peter Cushing  4.499357e+08
# 1      Robert Downey Jr.  3.385169e+08
# 2              Ed Skrein  3.050243e+08
# 3        Leonard Roberts  2.913236e+08
# 4      Jennifer Saunders  2.864710e+08
# ...                  ...           ...
# 2184  Robin Atkin Downes -1.070511e+09
# 2185       Takeshi Kusao -1.099561e+09
# 2186     Péter Fancsikai -2.499804e+09
# 2187        Yeong-ae Lee -4.199788e+09
# 2188        Kang-ho Song -1.221330e+10
#
# [2189 rows x 2 columns]

# %%
actor_3 = df_people.groupby(["actor_3_name"])[["profit"]].agg("mean").sort_values(by = "profit", ascending=False).reset_index()
actor_3
# Out:
#           actor_3_name        profit
# 0              Omar Sy  5.021773e+08
# 1        Gloria Stuart  4.586723e+08
# 2        Niketa Calame  3.777838e+08
# 3        Ian McDiarmid  3.595447e+08
# 4     Anthony Reynolds  3.299993e+08
# ...                ...           ...
# 2583      Tesshô Genda -1.099561e+09
# 2584    Hye-jeong Kang -2.100304e+09
# 2585    Rosalind Ayres -2.127110e+09
# 2586     Bálint Péntek -2.499804e+09
# 2587        Ah-sung Ko -1.221330e+10
#
# [2588 rows x 2 columns]

# %%
director_high = list(director.loc[director["profit"] > 0]["director_name"])
director_high
# Out:
# ['Tim Miller',
#  'George Lucas',
#  'Richard Marquand',
#  'Kyle Balda',
#  'Colin Trevorrow',
#  'Chris Buck',
#  'Joss Whedon',
#  'Yarrow Cheney',
#  'Pierre Coffin',
#  'Lee Unkrich',
#  'Roger Allers',
#  'William Cottrell',
#  'James Cameron',
#  'Peter Faiman',
#  'Pete Docter',
#  'Francis Lawrence',
#  'Irvin Kershner',
#  'Daniel Myrick',
#  'Andrew Adamson',
#  'Joel Zwick',
#  'Sam Taylor-Johnson',
#  'George Roy Hill',
#  'Phil Lord',
#  'Josh Boone',
#  'Gary Ross',
#  'Peter Farrelly',
#  'Jon Favreau',
#  'David Silverman',
#  'Oren Peli',
#  'Victor Fleming',
#  'Penelope Spheeris',
#  'Robert Wise',
#  'Christopher Nolan',
#  'Leonard Nimoy',
#  'Steven Spielberg',
#  'Shane Black',
#  'Randal Kleiser',
#  'Robert Stevenson',
#  'John Lasseter',
#  'Michael Sucsy',
#  'Rawson Marshall Thurber',
#  'John G. Avildsen',
#  'John Cornell',
#  'Jay Roach',
#  'Chris Miller',
#  'Paul Tibbitt',
#  'Mike Gabriel',
#  'Chris Columbus',
#  'Todd Phillips',
#  'Jeannot Szwarc',
#  'Tod Williams',
#  'Norman Ferguson',
#  'Jeff Tremaine',
#  'P.J. Hogan',
#  'David Slade',
#  'Jim Abrahams',
#  'Elizabeth Banks',
#  'Genndy Tartakovsky',
#  'Igor Kovalyov',
#  'Carlos Saldanha',
#  'Seth Gordon',
#  'Henry Joost',
#  'James Wan',
#  'Ben Affleck',
#  'Bruce Beresford',
#  'Tate Taylor',
#  'Mel Brooks',
#  'Herbert Ross',
#  'Peter Jackson',
#  'Luc Jacquet',
#  'Dan Scanlon',
#  'John Badham',
#  'Tom Hooper',
#  'Alfonso Cuarón',
#  'Gabor Csupo',
#  'James DeMonaco',
#  'Anthony Russo',
#  'Jerry Zucker',
#  'Seth MacFarlane',
#  'Robert Stromberg',
#  'Takashi Shimizu',
#  'Chris Wedge',
#  'Bill Condon',
#  'Tom Shadyac',
#  'Jason Reitman',
#  'Mike McCoy',
#  'Tim Story',
#  'Don Hall',
#  'Sydney Pollack',
#  'Judd Apatow',
#  'Dan Trachtenberg',
#  'Adrian Lyne',
#  'Nicholas Meyer',
#  'Stephen Hillenburg',
#  'Jim Gillespie',
#  'George Cukor',
#  'Phyllida Lloyd',
#  'Lee Daniels',
#  'Michael Pressman',
#  'Mark Andrews',
#  'Mike Mitchell',
#  'Garry Marshall',
#  'Jonathan Dayton',
#  'J.J. Abrams',
#  'David F. Sandberg',
#  'Andrés Muschietti',
#  'Sam Raimi',
#  'Howard Zieff',
#  'Tim Burton',
#  'Gregory Jacobs',
#  'John Landis',
#  'James Gunn',
#  'Peyton Reed',
#  'Tim Johnson',
#  'Phil Alden Robinson',
#  'Etan Cohen',
#  'Catherine Hardwicke',
#  'Dean DeBlois',
#  'Tim Hill',
#  'Michael Bay',
#  'Darren Lynn Bousman',
#  'Greg Mottola',
#  'Ben Falcone',
#  'Peter Billingsley',
#  'Steve Martino',
#  'M. Night Shyamalan',
#  'Jason Moore',
#  'J.B. Rogers',
#  'Luis Valdez',
#  'Andrew Stanton',
#  'Stig Bergqvist',
#  'Jared Hess',
#  'Nicholas Stoller',
#  'David Hackl',
#  'Stiles White',
#  'Sharon Maguire',
#  'Kevin Costner',
#  'Andrew Douglas',
#  'Ryan Coogler',
#  'Darren Grant',
#  'Wes Ball',
#  'Olivier Megaton',
#  'Anne Fletcher',
#  'Betty Thomas',
#  'Thomas Carter',
#  'David Frankel',
#  'Nima Nourizadeh',
#  'David O. Russell',
#  'Robert Zemeckis',
#  'Leigh Whannell',
#  'John R. Leonetti',
#  'Cody Cameron',
#  'Tyler Perry',
#  'Milos Forman',
#  'Nancy Meyers',
#  'David Carson',
#  'Quentin Tarantino',
#  'R.J. Cutler',
#  'Eugenio Derbez',
#  'Sam Miller',
#  'Daniel Stamm',
#  'Joe Camp',
#  'Raja Gosnell',
#  'David S. Ward',
#  'Joel Edgerton',
#  'Eric Brevig',
#  'Paul Feig',
#  'Michael Moore',
#  'Andy Tennant',
#  'Dennis Dugan',
#  'Christopher Spencer',
#  'Jerome Robbins',
#  'James Watkins',
#  'Fede Alvarez',
#  'John Pasquin',
#  'Gore Verbinski',
#  'Stanley Kramer',
#  'Ivan Reitman',
#  'Anthony Minghella',
#  'Thea Sharrock',
#  'Peter Weir',
#  'Ole Bornedal',
#  'Colin Higgins',
#  'Chris Weitz',
#  'Sylvester Stallone',
#  'Peter Segal',
#  'Sam Mendes',
#  'Kenny Ortega',
#  'Clay Kaytis',
#  'Adam Shankman',
#  'Alexander Payne',
#  'Martin Brest',
#  'Hugh Wilson',
#  'Rupert Wyatt',
#  'Michael Lembeck',
#  'David Zucker',
#  'Cory Edwards',
#  'Larry Charles',
#  'Bob Clark',
#  'Zack Snyder',
#  'Josh Gordon',
#  'Shawn Levy',
#  'Penny Marshall',
#  'Chuck Russell',
#  'Kevin Rodney Sullivan',
#  'John Lee Hancock',
#  'Clint Eastwood',
#  'Chris Stokes',
#  'Ava DuVernay',
#  'Francis Ford Coppola',
#  'Cecil B. DeMille',
#  'Steve Carr',
#  'Ethan Coen',
#  'Boaz Yakin',
#  'Christopher Cain',
#  'Lewis Gilbert',
#  'George P. Cosmatos',
#  'William Friedkin',
#  'Tobe Hooper',
#  'David Lean',
#  'Steve Oedekerk',
#  'Eric Darnell',
#  'Brenda Chapman',
#  'Alfred Hitchcock',
#  'Theodore Melfi',
#  'Henry Koster',
#  "Dinesh D'Souza",
#  'Joseph Zito',
#  'Terence Young',
#  'William Brent Bell',
#  'Will Gluck',
#  'Tony Bancroft',
#  'Andy Fickman',
#  'John Luessenhop',
#  'Levan Gabriadze',
#  'Adam McKay',
#  'Guy Hamilton',
#  'Michael McCullers',
#  'F. Gary Gray',
#  'Forest Whitaker',
#  'Patty Jenkins',
#  'Paul Greengrass',
#  'Leslie Small',
#  'Michel Hazanavicius',
#  'Joe Roth',
#  'Brad Bird',
#  'Jonathan Demme',
#  'Ron Clements',
#  'Roger Michell',
#  'Matt Reeves',
#  'Aaron Seltzer',
#  'Ron Howard',
#  'Don Siegel',
#  'Robin Budd',
#  'Andrew Davis',
#  'Ric Roman Waugh',
#  'Steve Trenbirth',
#  'John Francis Daley',
#  'Mennan Yapo',
#  'Kenneth Branagh',
#  'Jack Sholder',
#  'Michael Dougherty',
#  'Barry Sonnenfeld',
#  'Christopher Landon',
#  'Paul Haggis',
#  'William Shatner',
#  'John Crowley',
#  'Mick Jackson',
#  'Robert Luketic',
#  'Martin Lawrence',
#  'Joseph L. Mankiewicz',
#  'Steve Box',
#  'Dave Green',
#  'Brian Levant',
#  'Jim Fall',
#  'Stuart Gillard',
#  'Audrey Wells',
#  'Ari Sandel',
#  'Steven Soderbergh',
#  'Michael Tiddes',
#  'Charles Herman-Wurmfeld',
#  'John Hamburg',
#  'Jesse Dylan',
#  'Alex Kendrick',
#  'John Singleton',
#  'Richard Lester',
#  'Frank Marshall',
#  'Stanley Tong',
#  'Mark Tonderai',
#  'Gus Van Sant',
#  'Rich Moore',
#  'Perry Andelin Blake',
#  'Bobby Farrelly',
#  'Dan Mazer',
#  'Morten Tyldum',
#  'Gabriele Muccino',
#  'Nelson McCormick',
#  'D.J. Caruso',
#  'Dan Gilroy',
#  'John Glen',
#  'Bennett Miller',
#  'Luke Greenfield',
#  'Jan de Bont',
#  'Michael Schultz',
#  'Sylvain White',
#  'Ted Demme',
#  'John Madden',
#  'Mike Flanagan',
#  'Travis Cluff',
#  'Kirk De Micco',
#  'Guy Ritchie',
#  'David Gelb',
#  'Mark Waters',
#  'David Kellogg',
#  'Wes Craven',
#  'Peter Lepeniotis',
#  'Malcolm D. Lee',
#  'Billy Wilder',
#  'Len Wiseman',
#  'Joel Gallen',
#  'Thor Freudenthal',
#  'Robert Eggers',
#  'William Wyler',
#  'Danny Leiner',
#  'Joseph Gordon-Levitt',
#  'Gary Hardwick',
#  'David Fincher',
#  'Christian E. Christiansen',
#  'Rob Marshall',
#  'Rob Cohen',
#  'Chris Koch',
#  'Kevin Greutert',
#  'Paul King',
#  'Rupert Wainwright',
#  'Bernardo Bertolucci',
#  'Charles Martin Smith',
#  'Paul Weitz',
#  'Barbra Streisand',
#  'Bibo Bergeron',
#  'Mark Rydell',
#  'Christopher McQuarrie',
#  'Terry Zwigoff',
#  'Callie Khouri',
#  'Jonathan Liebesman',
#  'John Polson',
#  'John Hoffman',
#  'David Yates',
#  'John Erick Dowdle',
#  'Bob Dolman',
#  'Chris Kentis',
#  'Joe Dante',
#  'Marc Webb',
#  'Tamra Davis',
#  'Scott Derrickson',
#  'Jesse Peretz',
#  'Gene Quintano',
#  'Angelina Jolie Pitt',
#  'Jon Turteltaub',
#  'Gina Prince-Bythewood',
#  'Neil Burger',
#  'David Moreau',
#  'Rob Reiner',
#  'Christopher Erskin',
#  'Danny Steinmann',
#  'Salim Akil',
#  'Peter Lord',
#  'Phil Traill',
#  'Matt Williams',
#  'Preston A. Whitmore II',
#  'Ice Cube',
#  'Gary Winick',
#  'Tom McGrath',
#  'Mike Judge',
#  'Juan José Campanella',
#  'Jonathan Levine',
#  'Mary Lambert',
#  'Tom Gormican',
#  'Keenen Ivory Wayans',
#  'Masayuki Ochiai',
#  'Ciarán Foy',
#  'Dennis Iliadis',
#  'Stanley Kubrick',
#  'Ang Lee',
#  'Jay Russell',
#  'Lee Toland Krieger',
#  'Michael Ritchie',
#  'Patricia Riggen',
#  'David Wain',
#  'Jaume Collet-Serra',
#  'Lisa Cholodenko',
#  'Nick Cassavetes',
#  'Sean Anders',
#  'Jamie Blanks',
#  'Bradley Parker',
#  'Steve McQueen',
#  'Eli Roth',
#  'Adrienne Shelly',
#  'Cal Brunker',
#  'Robert Iscove',
#  'Steven Brill',
#  'Robert Rodriguez',
#  'Mimi Leder',
#  'Harold Ramis',
#  'Nora Ephron',
#  'Jason Zada',
#  'Randall Wallace',
#  'Nat Faxon',
#  "John 'Bud' Cardos",
#  'Tom McLoughlin',
#  'Luis Llosa',
#  'Greg Coolidge',
#  'Jon Hurwitz',
#  'Alejandro G. Iñárritu',
#  'John Carl Buechler',
#  'Mark Brown',
#  'Steve Pink',
#  'Ethan Maniquis',
#  'Joe Carnahan',
#  'Todd Strauss-Schulson',
#  'Michael Anderson',
#  'Ed Decter',
#  'Peter R. Hunt',
#  'Evan Goldberg',
#  'Harold Cronk',
#  'Robert Duvall',
#  'Stephen Sommers',
#  'Ruben Fleischer',
#  'Jun Falkenstein',
#  'John Lafia',
#  'Olatunde Osunsanmi',
#  'Tom Holland',
#  'Gregory Nava',
#  'Neill Blomkamp',
#  'John Stainton',
#  'James Mangold',
#  'Brian Henson',
#  'Rick Rosenthal',
#  'Simon Curtis',
#  'Jennifer Yuh Nelson',
#  'Morgan Spurlock',
#  'Tom McCarthy',
#  'Barry Levinson',
#  'Mark A.Z. Dippé',
#  'Jon M. Chu',
#  'Kirk Jones',
#  'Cathy Malkasian',
#  'Jake Kasdan',
#  'Baltasar Kormákur',
#  'Melvin Van Peebles',
#  'Jonathan Lynn',
#  'Julie Anne Robinson',
#  'John A. Davis',
#  'Peter Hedges',
#  'Maurice Joyce',
#  'John Eng',
#  'Gurinder Chadha',
#  'Sara Sugarman',
#  'George Jackson',
#  'Ken Kwapis',
#  'Charles Stone III',
#  'Louis Leterrier',
#  'Kirk Wong',
#  'Gary David Goldberg',
#  'George Tillman Jr.',
#  'Joel Schumacher',
#  'Rick Famuyiwa',
#  'Jessie Nelson',
#  'Chuck Sheetz',
#  'Juan Carlos Fresnadillo',
#  'Clive Barker',
#  'David S. Goyer',
#  'Bronwen Hughes',
#  'Adam Marcus',
#  'John Patrick Shanley',
#  'John Fortenberry',
#  'Dan Cutforth',
#  'John Whitesell',
#  'Rob McKittrick',
#  'Tom Vaughan',
#  'David E. Talbert',
#  'Rowdy Herrington',
#  'Tony Scott',
#  'Marcus Raboy',
#  'Rob Pritts',
#  'Hugh Hudson',
#  'Pierre Morel',
#  'Michael Wadleigh',
#  'Gonzalo López-Gallego',
#  'Jon Lucas',
#  'David Robert Mitchell',
#  'Brett Ratner',
#  'Phillip Noyce',
#  'King Vidor',
#  'Mike Figgis',
#  'Kevin Lima',
#  'Alejandro Agresti',
#  'George Nolfi',
#  'Victor Salva',
#  'Drew Goddard',
#  'Denzel Washington',
#  'Tommy Lee Wallace',
#  'Chris Nahon',
#  'Peter Cattaneo',
#  'David Palmer',
#  'Trent Cooper',
#  'Kevin Macdonald',
#  'Jim Field Smith',
#  'John Schlesinger',
#  'Miguel Arteta',
#  'James Marsh',
#  'Joe Berlinger',
#  'Jay Chandrasekhar',
#  'Tim McCanlies',
#  'Mark Rosman',
#  'Darren Aronofsky',
#  'David McNally',
#  'Paul Michael Glaser',
#  'Trey Parker',
#  'Kris Isacsson',
#  'Tim Blake Nelson',
#  'Jennifer Flackett',
#  'Benh Zeitlin',
#  'Antoine Fuqua',
#  'Zach Braff',
#  'Frank Darabont',
#  'Daniel Barnz',
#  'Patrick Tatopoulos',
#  'Danny Boyle',
#  'Newt Arnold',
#  'Tuck Tucker',
#  'Sean McNamara',
#  'Denis Villeneuve',
#  'Bryan Singer',
#  'Michael Gornick',
#  'Roland Emmerich',
#  'Scott Hicks',
#  'Scott Cooper',
#  'Joe Pytka',
#  'Alex Garland',
#  'Jake Schreier',
#  'Diane English',
#  'Robert Ben Garant',
#  'Brian De Palma',
#  'Dean Israelite',
#  'Gillian Armstrong',
#  'Eric Leighton',
#  'Rob Zombie',
#  'Ed Gass-Donnelly',
#  'Joe Chappelle',
#  'Mark Helfrich',
#  'Rian Johnson',
#  'Michael Spierig',
#  'Damien Chazelle',
#  'John McNaughton',
#  'Dwight H. Little',
#  'John Carpenter',
#  'Chia-Liang Liu',
#  'Brad Peyton',
#  'Kevin Reynolds',
#  'Carter Smith',
#  'Rob Hedden',
#  'Richard Donner',
#  'Harmony Korine',
#  'Glenn Ficarra',
#  'Ben Younger',
#  'Rick Friedberg',
#  'Elizabeth Allen Rosenbaum',
#  'Richard Curtis',
#  'Matt Bettinelli-Olpin',
#  'Christian Ditter',
#  'Bille Woodruff',
#  'John Carney',
#  'Jonas Elmer',
#  'Elia Kazan',
#  'Bonnie Hunt',
#  'Dominique Othenin-Girard',
#  'Niki Caro',
#  'Steve Beck',
#  'Timur Bekmambetov',
#  'Walt Becker',
#  'Jason Friedberg',
#  'Phil Joanou',
#  'George Clooney',
#  'Wayne Wang',
#  'Mickey Liddell',
#  "Matthew O'Callaghan",
#  'David R. Ellis',
#  'Leon Ichaso',
#  'Lasse Hallström',
#  'Gregory Widen',
#  'Albert Hughes',
#  'Russ Meyer',
#  'Ernest R. Dickerson',
#  'Edward Burns',
#  'Tom Dey',
#  'Brett Leonard',
#  'Mary Harron',
#  'Mikael Håfström',
#  'Amy Heckerling',
#  'John McTiernan',
#  'Duncan Tucker',
#  'Donald Petrie',
#  'Fred Walton',
#  'Chris Rock',
#  'Sam Weisman',
#  'Cameron Crowe',
#  'Oliver Stone',
#  'Ryan Murphy',
#  'Patricia Rozema',
#  'Steve Bendelack',
#  'Richard Glatzer',
#  'John Ottman',
#  'Wes Anderson',
#  'Grant Heslov',
#  'Dustin Hoffman',
#  'Clare Kilner',
#  'Mike Binder',
#  'Jane Campion',
#  'Fred Savage',
#  'Steve Carver',
#  'Baz Luhrmann',
#  'Peter Hewitt',
#  'Troy Miller',
#  'Neil LaBute',
#  'Jean-Marc Vallée',
#  'Edward Norton',
#  'Benny Boom',
#  'Stephen Daldry',
#  'Reginald Hudlin',
#  'Todd Field',
#  'Michael Martin',
#  'Carol Reed',
#  'Doug Liman',
#  'Stephen Norrington',
#  'Frank Coraci',
#  'Asghar Farhadi',
#  'Colin Strause',
#  'Clark Johnson',
#  'Xavier Gens',
#  'Alan J. Pakula',
#  'Kevin Smith',
#  'Angela Robinson',
#  'Derek Cianfrance',
#  'Alexandre Aja',
#  'Sheldon Lettich',
#  'Paul Weiland',
#  'Jody Hill',
#  'Terry George',
#  'Martin Weisz',
#  'Rusty Cundieff',
#  'Joby Harold',
#  'Peter Sollett',
#  'Alexander Witt',
#  'Peter Atencio',
#  'Brian Klugman',
#  'Stephen Frears',
#  'Kevin Tenney',
#  'David Mirkin',
#  'Spike Lee',
#  'Nicole Holofcener',
#  'Danny Cannon',
#  'Robert Townsend',
#  'Robert Marcarelli',
#  'Anthony Bell',
#  'Don Mancini',
#  'Ben Lewin',
#  'Jonathan Frakes',
#  'David Raynr',
#  'DJ Pooh',
#  'Brandon Camp',
#  'John Milius',
#  'Fred Wolf',
#  'Christopher Leitch',
#  'Jeff Wadlow',
#  'Alejandro Monteverde',
#  'Eugène Lourié',
#  'Chris Noonan',
#  'Matt Maiellaro',
#  'Stephen Chbosky',
#  'Anton Corbijn',
#  'Chris Eyre',
#  'Robert Altman',
#  'Liz Friedlander',
#  'Brad Anderson',
#  'James Wong',
#  'Nicholas Hytner',
#  'Mike Nawrocki',
#  'Mamoru Hosoda',
#  'Debra Granik',
#  'Curtis Hanson',
#  'James Ponsoldt',
#  'Craig Brewer',
#  'Simon West',
#  'Don Coscarelli',
#  'Bob Spiers',
#  'George Sidney',
#  'Tomas Alfredson',
#  'Nnegest Likké',
#  'Christine Jeffs',
#  'Todd Solondz',
#  'Lana Wachowski',
#  'Morgan Neville',
#  'Carlos Carrera',
#  'Steve Miner',
#  'Patrick Stettner',
#  'Brian Helgeland',
#  'John Schultz',
#  'Harry Elfont',
#  'Brian Dannelly',
#  'Richard Linklater',
#  'Kevin Tancharoen',
#  'Sam Firstenberg',
#  'Louis Morneau',
#  'Brad Furman',
#  'Gary Sherman',
#  'Mark Christopher',
#  'Joshua Marston',
#  'Mark Romanek',
#  'Nicolas Winding Refn',
#  'Lone Scherfig',
#  'Victor Nunez',
#  'Geoffrey Sax',
#  'Ritesh Batra',
#  'John Wells',
#  'Drake Doremus',
#  'Dennie Gordon',
#  'Allen Coulter',
#  'Mark Pellington',
#  'Gareth Evans',
#  'Jaume Balagueró',
#  'Brendan Malloy',
#  'Patricia Cardoso',
#  'Rob Schmidt',
#  'Gil Junger',
#  'Brian Baugh',
#  'Craig R. Baxley',
#  'Mark Osborne',
#  'Rachel Talalay',
#  'Whit Stillman',
#  'Tim Hunter',
#  'Tom Hanks',
#  'Andrzej Bartkowiak',
#  'Ed Harris',
#  'Bill Duke',
#  'Gregory Poirier',
#  'Sofia Coppola',
#  'Theodore Witcher',
#  'Brian Percival',
#  'Alan Poul',
#  'Burr Steers',
#  'Tommy Wirkola',
#  'Marc Lawrence',
#  'Harry Beaumont',
#  'David Nutter',
#  'Babak Najafi',
#  'Mark Sandrich',
#  'Franco Zeffirelli',
#  'Brad Silberling',
#  "Damien O'Donnell",
#  'Troy Duffy',
#  'Matty Rich',
#  'Justin Lin',
#  'Tom Ford',
#  'Julian Jarrold',
#  'Bill Paxton',
#  'Mike Newell',
#  'Scott Speer',
#  'Ronny Yu',
#  'Frank Oz',
#  'Ryan Fleck',
#  'Neil Jordan',
#  'Maggie Carey',
#  'Miranda July',
#  'Lloyd Bacon',
#  'Richard Attenborough',
#  'Stephen Herek',
#  'J.S. Cardone',
#  'Shane Acker',
#  'Neil Marshall',
#  'Maria Maggenti',
#  'Noah Baumbach',
#  'Jim Hanon',
#  'Christopher Guest',
#  'Lenny Abrahamson',
#  'Aaron Schneider',
#  'David Boyd',
#  'Kirsten Sheridan',
#  'Susan Seidelman',
#  'James Isaac',
#  'Max Joseph',
#  'Barry W. Blaustein',
#  'James McTeigue',
#  'Courtney Hunt',
#  'Kimberly Peirce',
#  'Michael Tollin',
#  'Stephan Elliott',
#  'Norman Jewison',
#  'Robert Harmon',
#  'Maggie Greenwald',
#  'Émile Gaudreault',
#  'Mike Cahill',
#  'Jay Levey',
#  'Michael Rymer',
#  'Andrew Fleming',
#  'Peter M. Cohen',
#  'Siddiq Barmak',
#  'Alan Cohn',
#  'Jon Kasdan',
#  'Garth Jennings',
#  'Joe Johnston',
#  'David Gordon Green',
#  'Shana Feste',
#  'Anthony Hickox',
#  'Russell Mulcahy',
#  'Risa Bramon Garcia',
#  'Brian Gibson',
#  'Sidney Lumet',
#  'James Ivory',
#  'Jon Shear',
#  'Mike Marvin',
#  'Ari Folman',
#  'Tarsem Singh',
#  'Majid Majidi',
#  'Patrick Lussier',
#  'Greg Berlanti',
#  'Wolfgang Petersen',
#  'Alejandro Amenábar',
#  'Roger Avary',
#  'John Gatins',
#  'Jonathan Hensleigh',
#  'Chris Paine',
#  'Kevin Bray',
#  'Raymond De Felitta',
#  'Jafar Panahi',
#  'Kevin Munroe',
#  'Piyush Dinker Pandya',
#  'Edgar Wright',
#  'Damien Dante Wayans',
#  'RZA',
#  'Cristian Mungiu',
#  'Jonathan Caouette',
#  'Michael Patrick Jann',
#  'Tom Schulman',
#  'Don Michael Paul',
#  'Nimród Antal',
#  'Tamara Jenkins',
#  'Myles Berkowitz',
#  'Marc Forster',
#  'Shane Carruth',
#  'Joseph Dorman',
#  'Jamie Travis',
#  'Dean Parisot',
#  'Andrew Haigh',
#  'Peter Kosminsky',
#  'Greg Harrison',
#  'Lena Dunham',
#  'Saul Dibb',
#  'Kelly Reichardt',
#  'Allison Anders',
#  'Fernando Meirelles',
#  'Jeff Burr',
#  'Louis C.K.',
#  'Robert Redford',
#  'Mike Bigelow',
#  'Michael Mayer',
#  'Jim Sonzero',
#  'Mark Illsley',
#  'Jamie Babbit',
#  'Kevin Jordan',
#  'Beeban Kidron',
#  'George A. Romero',
#  'Jorge R. Gutiérrez',
#  'Warren Beatty',
#  'Jacob Aaron Estes',
#  'Larry Blamire',
#  'Steven Quale',
#  'Craig Zobel',
#  'Martin Scorsese']

# %%
director_low = list(director.loc[director["profit"] <= 0]["director_name"])
director_low
# Out:
# ['Hunter Richards',
#  'Michel Orion Scott',
#  'Woody Allen',
#  'Marc Levin',
#  'Brandon Trost',
#  'Jean-François Richet',
#  'Cédric Klapisch',
#  'George Miller',
#  'Joe Swanberg',
#  'Bill Plympton',
#  'Mike Mills',
#  'Xavier Beauvois',
#  'Ricky Gervais',
#  'Hans Canosa',
#  'Clark Gregg',
#  'John Sayles',
#  'Richard LaGravenese',
#  'Matt Piedmont',
#  'Tom Putnam',
#  'Eric Valette',
#  'E.L. Katz',
#  'Steve James',
#  'Jon Gunn',
#  "Eddie O'Flaherty",
#  'Ricki Stern',
#  'Richard Dutcher',
#  'Eric Schaeffer',
#  'Henry Alex Rubin',
#  'Nadine Labaki',
#  'C. Jay Cox',
#  'Neema Barnette',
#  'Gareth Edwards',
#  'Lucio Fulci',
#  'Fabián Bielinsky',
#  'Bruce Dellis',
#  'Jon Amiel',
#  'Julian Schnabel',
#  'Lucky McKee',
#  'Quentin Dupieux',
#  'Darren Stein',
#  'Nick Tomnay',
#  'Rob Letterman',
#  'Peter Landesman',
#  'Ben Wheatley',
#  'Steve Buscemi',
#  'Lloyd Kaufman',
#  'Alex Smith',
#  'David Ayer',
#  'Alex Craig Mann',
#  'Josef Rusnak',
#  'Joshua Oppenheimer',
#  'Marielle Heller',
#  'François Girard',
#  'Finn Taylor',
#  'Karen Moncrieff',
#  'Tim Robbins',
#  'Nick Gomez',
#  'Michael Polish',
#  'Scott Ziehl',
#  'Sally Potter',
#  'Steve Taylor',
#  'Jim Mickle',
#  'John Michael McDonagh',
#  'David Nixon',
#  'Rich Cowan',
#  'Pawel Pawlikowski',
#  'Anthony Powell',
#  'Efram Potelle',
#  'Alex Gibney',
#  'Ti West',
#  'Wolfgang Becker',
#  'Vincente Minnelli',
#  'Tom Green',
#  'Paul Verhoeven',
#  'Rebecca Miller',
#  'Tony Kaye',
#  'Rich Christiano',
#  'Caroline Link',
#  'Kasi Lemmons',
#  'Ben Stiller',
#  'Richard Eyre',
#  'Paul Crowder',
#  'David Sington',
#  'Oliver Blackburn',
#  'Stephen Kay',
#  'Ramaa Mosley',
#  'Goran Dukic',
#  'Gary Rogers',
#  'Johnny Remo',
#  'Kat Coiro',
#  'Benjamin Dickinson',
#  'Ham Tran',
#  'Troy Nixey',
#  'Randall Miller',
#  'Peter Chelsom',
#  'Jonathan Kesselman',
#  'Eric Nicholas',
#  'Hal Haberman',
#  'Morgan J. Freeman',
#  'Panos Cosmatos',
#  'Richard Fleischer',
#  'Michael Cuesta',
#  'Henry Bean',
#  'Lucrecia Martel',
#  'Kurt Voss',
#  'John Bonito',
#  'Shane Meadows',
#  'Jeff Franklin',
#  'Jill Sprecher',
#  'Alison Maclean',
#  'Robert Lee King',
#  'Jeremy Saulnier',
#  'Jeff Garlin',
#  'Sidney J. Furie',
#  'Bruce Campbell',
#  'Charles Chaplin',
#  'Michael Hoffman',
#  'Zak Penn',
#  'Pete Jones',
#  'Pascal Arnold',
#  'Griffin Dunne',
#  'Ron Fricke',
#  'Robby Henson',
#  'Jamal Hill',
#  'Zach Cregger',
#  'Alessandro Carloni',
#  'Bruce McDonald',
#  'Frank Whaley',
#  'Michael Herz',
#  'Jorma Taccone',
#  'Joe Nussbaum',
#  'Stuart Baird',
#  'Tony Maylam',
#  'François Truffaut',
#  'Steven E. de Souza',
#  'Jonas Åkerlund',
#  'Isabel Coixet',
#  'Mark Tarlov',
#  'Adam Goldberg',
#  'Anna Boden',
#  'Akira Kurosawa',
#  'Mira Nair',
#  'Spike Jonze',
#  'Jon Hess',
#  'Wallace Wolodarsky',
#  'Laurie Collyer',
#  'Deb Hagan',
#  'Michel Gondry',
#  'Bruce McCulloch',
#  'Michael Landon Jr.',
#  'Christophe Barratier',
#  'Lance Mungia',
#  'Jon Stewart',
#  'Steven R. Monroe',
#  'Frank Nissen',
#  'John Cameron Mitchell',
#  'James Mottern',
#  'Drew Barrymore',
#  'Rodrigo Cortés',
#  'Jeff Nichols',
#  'Ralph Ziman',
#  'Paul Bunnell',
#  'Vic Armstrong',
#  'Scott Frank',
#  'Jesse Vaughan',
#  'Jessy Terrero',
#  'Justin Kerrigan',
#  'Craig Gillespie',
#  'Douglas Aarniokoski',
#  'David Mamet',
#  'Jason Bateman',
#  'Joseph Sargent',
#  'James Toback',
#  'Joan Chen',
#  'Carmen Marron',
#  'Mitch Davis',
#  'Dan Rush',
#  'Orson Welles',
#  'Jason Eisener',
#  'Gilles Paquet-Brenner',
#  'Joshua Tickell',
#  "Gavin O'Connor",
#  'Brian Robbins',
#  'Tony Richardson',
#  'Reed Cowan',
#  'Barry Skolnick',
#  'Tony Gilroy',
#  'Alex Rivera',
#  'Michael D. Sellers',
#  'Jeff Lowell',
#  'Bryan Barber',
#  'Tony Goldwyn',
#  'Michael J. Bassett',
#  'Sylvain Chomet',
#  'Philip G. Atwell',
#  'Wayne Kramer',
#  'Nacho Vigalondo',
#  'Denys Arcand',
#  'Leslye Headland',
#  'Courtney Solomon',
#  'Salvador Carrasco',
#  'Jay Duplass',
#  'Stefan Schwartz',
#  'Roger Kumble',
#  'Don Bluth',
#  'Emilio Estevez',
#  'Tim Heidecker',
#  'Jeremy Leven',
#  'Kathryn Bigelow',
#  'Mark L. Lester',
#  'Jodie Foster',
#  'Vincent Paronnaud',
#  'Huck Botko',
#  'Jason Alexander',
#  'Mark Steven Johnson',
#  'Nick Love',
#  'Fina Torres',
#  'Kenneth Lonergan',
#  'Frank LaLoggia',
#  'Paul Schrader',
#  'Scott Alexander',
#  'Christophe Gans',
#  'Bob Saget',
#  'Fenton Bailey',
#  'J Blakeson',
#  'Britt Allcroft',
#  'Dave McKean',
#  'Marcus Dunstan',
#  'Ruggero Deodato',
#  'Aki Kaurismäki',
#  'Katt Shea',
#  'Paul Gross',
#  'Robert Cary',
#  'Kevin Allen',
#  'Stephen J. Anderson',
#  'Charles Robert Carner',
#  'Lorene Scafaria',
#  'Albert Brooks',
#  'Adam Rapp',
#  'David Dobkin',
#  'Mars Callahan',
#  'Martin Koolhoven',
#  'Peter Stebbings',
#  'Mark Herman',
#  'William Malone',
#  'Timothy Björklund',
#  'Derrick Borte',
#  'Anna Muylaert',
#  'Martin McDonagh',
#  'Noam Murro',
#  'Pete Travis',
#  'Hart Bochner',
#  'Michael Corrente',
#  'Hue Rhodes',
#  'Dan Harris',
#  'Harald Zwart',
#  'Dagur Kári',
#  'Paul Thomas Anderson',
#  'Sam Peckinpah',
#  'Mike van Diem',
#  'Billy Ray',
#  'Daniel Espinosa',
#  'Fernando León de Aranoa',
#  'Steve Gomer',
#  'Richard Raymond',
#  'Darnell Martin',
#  'Thomas Bezucha',
#  'Edward Zwick',
#  'James Cox',
#  'Scott Kalvert',
#  'Glen Morgan',
#  'David Atkins',
#  'Karim Aïnouz',
#  'Chris Butler',
#  'Olivier Assayas',
#  'Stewart Hendler',
#  'Joe Charbanic',
#  'Nicholas Jarecki',
#  'Michel Leclerc',
#  'Tom Kalin',
#  'Yash Chopra',
#  'Stephen Gaghan',
#  'Zal Batmanglij',
#  'Rick de Oliveira',
#  'Paul Abascal',
#  'Rob Bowman',
#  'Rodrigo García',
#  'Bart Freundlich',
#  'Vincent Gallo',
#  'Agnieszka Wojtowicz-Vosloo',
#  'Todd Graff',
#  'Vincenzo Natali',
#  'Sterling Van Wagenen',
#  'Mark Piznarski',
#  'John Boorman',
#  'Irwin Winkler',
#  'John Waters',
#  'Duke Johnson',
#  'Josh Schwartz',
#  'Michael Patrick King',
#  'Joshua Michael Stern',
#  'Robert Schwentke',
#  'Vadim Perelman',
#  'Kevin Brodie',
#  'Deon Taylor',
#  'Christopher Smith',
#  'Nicholas Fackler',
#  'Katherine Dieckmann',
#  'François Ozon',
#  'Klaus Menzel',
#  'Luca Guadagnino',
#  'Mel Gibson',
#  'Craig Mazin',
#  'Tim Chambers',
#  'Sylvio Tabet',
#  'Dean Wright',
#  'Michael McGowan',
#  'Lynne Ramsay',
#  'Gary Halvorson',
#  'Ridley Scott',
#  'Carl Franklin',
#  'Hitoshi Matsumoto',
#  'Daniel Barber',
#  'Alan Shapiro',
#  'Sergio Leone',
#  'Stuart Gordon',
#  'Terry Gilliam',
#  'Rick Bieber',
#  'David Duchovny',
#  'James Mather',
#  'Gary Fleder',
#  'Tomm Moore',
#  'Tina Gordon Chism',
#  'Joey Lauren Adams',
#  'S.R. Bindler',
#  'Philip Kaufman',
#  'John Moore',
#  'Fritz Lang',
#  'Franck Khalfoun',
#  'Susanna White',
#  'Mark Mylod',
#  'Alan Metter',
#  'Kelly Makin',
#  'John Stockwell',
#  'Dewey Nicks',
#  'Mike Leigh',
#  'J.C. Chandor',
#  'Stephen Chow',
#  'Richard Loncraine',
#  'Paolo Sorrentino',
#  'Rachel Perkins',
#  'David Twohy',
#  'Mark Neveldine',
#  'Floria Sigismondi',
#  'Michael Clancy',
#  'Oren Moverman',
#  'James Foley',
#  'Stephen Hopkins',
#  'Shari Springer Berman',
#  'Michael O. Sajbel',
#  'Spencer Susser',
#  'John Putch',
#  'Arie Posin',
#  'Richard E. Grant',
#  'Kelly Asbury',
#  'Damian Nieman',
#  "Thaddeus O'Sullivan",
#  'Todd Haynes',
#  'Peter Berg',
#  'Wil Shriner',
#  'Alister Grierson',
#  'Harley Cokeliss',
#  'Stephen Milburn Anderson',
#  'Terence Davies',
#  'Ruairi Robinson',
#  'Andy Garcia',
#  'Craig Bolotin',
#  'Nigel Cole',
#  'Richard Kelly',
#  'Marco Kreuzpaintner',
#  'Dexter Fletcher',
#  'Matthew Vaughn',
#  'Ol Parker',
#  'Jeff Schaffer',
#  'Steve Rash',
#  'Atom Egoyan',
#  'David Jacobson',
#  'Don Scardino',
#  'Joel Coen',
#  'Keith Gordon',
#  'Tom Brady',
#  'Måns Mårlind',
#  'Andrew Currie',
#  'Dominic Sena',
#  'Alex Proyas',
#  'Andrew Wilson',
#  'Marc Schölermann',
#  'Julio DePietro',
#  'Kevin Hooks',
#  'Robert Moresco',
#  'Meiert Avis',
#  'Daisy von Scherler Mayer',
#  'Blair Hayes',
#  'Dick Richards',
#  'Jon Poll',
#  'David Lynch',
#  'Luis Mandoki',
#  'Jez Butterworth',
#  'Marc Forby',
#  'Anthony Hemingway',
#  'William A. Graham',
#  'Charles T. Kanganis',
#  'Peter Medak',
#  'Steven Shainberg',
#  'Peter Howitt',
#  'Camille Delamarre',
#  'Scott Stewart',
#  'Eric Blakeney',
#  'Henry Hobson',
#  'Martin Campbell',
#  'Harold Becker',
#  'Les Mayfield',
#  'Brian Trenchard-Smith',
#  'Bo Welch',
#  'Chris Gorak',
#  'Vicky Jenson',
#  'Dario Argento',
#  'Walter Salles',
#  'James Bridges',
#  'Billy Bob Thornton',
#  'Joseph Kosinski',
#  'George Ratliff',
#  'Richard Kwietniowski',
#  'Ekachai Uekrongtham',
#  'E. Elias Merhige',
#  'Chris Carter',
#  'Lars von Trier',
#  'Gavin Hood',
#  'Bob Odenkirk',
#  'David Webb Peoples',
#  'Sam Fell',
#  'Graham Annable',
#  'Peter MacDonald',
#  'Simon Wincer',
#  'Joshua Seftel',
#  'Jim Sheridan',
#  'David Schwimmer',
#  'Damon Santostefano',
#  'Jeff Kanew',
#  'Stéphane Aubier',
#  'Takeshi Kitano',
#  'James Gray',
#  'George Hickenlooper',
#  'Fred Schepisi',
#  'Alex Zamm',
#  'Mel Smith',
#  'Kevin Donovan',
#  'Gary McKendry',
#  'Steve Barron',
#  'Antonia Bird',
#  'Geoff Murphy',
#  'Michael Meredith',
#  'Michael Dinner',
#  'Arthur Hiller',
#  'Scott Marshall',
#  'Álex de la Iglesia',
#  'William A. Fraker',
#  'James L. Brooks',
#  'Peter Kassovitz',
#  'Ken Scott',
#  'Jerry Zaks',
#  'Peter Care',
#  'István Szabó',
#  'Bruce Paltrow',
#  'David Cronenberg',
#  'Patrick Read Johnson',
#  'Ira Sachs',
#  'Guillermo del Toro',
#  'Lee Tamahori',
#  'Brian Koppelman',
#  'Agnieszka Holland',
#  'Nick Hamm',
#  'Michael Haneke',
#  'Kevin Spacey',
#  'Richard Shepard',
#  'John Hillcoat',
#  'Adam Rifkin',
#  'Andy Cadiff',
#  'Paul Mazursky',
#  'Stephen Carpenter',
#  'Ringo Lam',
#  'Sean Penn',
#  'Taylor Hackford',
#  'Jeffrey W. Byrd',
#  'Gregory Hoblit',
#  'Benson Lee',
#  'Lance Hool',
#  'J.A. Bayona',
#  'Carroll Ballard',
#  'Janusz Kaminski',
#  'Renny Harlin',
#  "Tommy O'Haver",
#  'Abel Ferrara',
#  'Michael Winterbottom',
#  'David Koepp',
#  'Werner Herzog',
#  'Steven Seagal',
#  'William Dear',
#  'Mort Nathan',
#  'Fred Durst',
#  'Douglas McGrath',
#  'Eric Bross',
#  'Je-kyu Kang',
#  'Tommy Lee Jones',
#  'Julie Taymor',
#  'Alan Rudolph',
#  'Chuan Lu',
#  'Joe Cornish',
#  'Matthew Robbins',
#  'George Stevens',
#  'Cyrus Nowrasteh',
#  'Iain Softley',
#  'Daniel Sackheim',
#  'Todd Lincoln',
#  'John Frankenheimer',
#  'Andrew Morahan',
#  'Roger Donaldson',
#  'George Gallo',
#  'Davis Guggenheim',
#  'Dave Borthwick',
#  'Ariel Vromen',
#  'Gaspar Noé',
#  'Ellory Elkayem',
#  'Fred Dekker',
#  'Philip Saville',
#  'Anand Tucker',
#  'Eric Bress',
#  'Oliver Parker',
#  'James Fargo',
#  'Antonio Banderas',
#  'Michael Chapman',
#  'Andrew Dominik',
#  'Richard Benjamin',
#  'Susanne Bier',
#  'Franklin J. Schaffner',
#  'Justin Zackham',
#  'Giuseppe Tornatore',
#  'Peter Hyams',
#  'Jonathan Teplitzky',
#  'Mic Rodgers',
#  'Rod Lurie',
#  'James Dodson',
#  'Christian Volckman',
#  'Mathieu Kassovitz',
#  'Jon Avnet',
#  'Uli Edel',
#  'Gary Shore',
#  'Nanette Burstein',
#  'Jerry Jameson',
#  'Michael Radford',
#  'Kenneth Johnson',
#  'Wayne Beach',
#  'Michael Mann',
#  'Hsiao-Hsien Hou',
#  'Ron Shelton',
#  'Alan Taylor',
#  'Anne Fontaine',
#  'Nick Hurran',
#  'Ray Lawrence',
#  'Gregor Jordan',
#  'Hal Needham',
#  'Jim Goddard',
#  "Pat O'Connor",
#  'Jonathan Kaplan',
#  'Rupert Sanders',
#  'Ryûhei Kitamura',
#  'McG',
#  'Dito Montiel',
#  'Vicente Amorim',
#  'Jake Paltrow',
#  'Jonathan Glazer',
#  'Noel Marshall',
#  'Stefan Ruzowitzky',
#  'Bruce Hunt',
#  'Kurt Wimmer',
#  'Udayan Prasad',
#  'Petter Næss',
#  'Gérard Krawczyk',
#  'Mike Nichols',
#  'George Armitage',
#  'Allen Hughes',
#  'Laurent Tirard',
#  'John Dahl',
#  'Jonathan Mostow',
#  'Gary Chapman',
#  'Steve Antin',
#  'Paul W.S. Anderson',
#  'Marc Abraham',
#  'John Curran',
#  'Alan Parker',
#  'Michael Lehmann',
#  'Rodman Flender',
#  'Michael Dowse',
#  'James Bobin',
#  'Mabrouk El Mechri',
#  'Andrew Niccol',
#  'Howard Deutch',
#  'Shekhar Kapur',
#  'Lawrence Guterman',
#  'Emile Ardolino',
#  'Matt Dillon',
#  'Terrence Malick',
#  'Frederik Du Chau',
#  'Florent-Emilio Siri',
#  'Justin Chadwick',
#  'Thomas Vinterberg',
#  'John Herzfeld',
#  'Kar-Wai Wong',
#  'Jean-Paul Rappeneau',
#  'Vondie Curtis-Hall',
#  'Angelo Pizzo',
#  'David Bowers',
#  'Jimmy Hayward',
#  'Li Zhang',
#  'Charlie Kaufman',
#  'Mark Dindal',
#  'Gary Trousdale',
#  'Karyn Kusama',
#  'Nancy Walker',
#  'Peter Hastings',
#  'Christian Alvart',
#  'Miguel Sapochnik',
#  'Russell Crowe',
#  'Chris Roberts',
#  'Michael Apted',
#  'Florian Henckel von Donnersmarck',
#  'Hyung-rae Shim',
#  'Willard Huyck',
#  'Joseph Kahn',
#  'Gordon Chan',
#  'Rowan Joffe',
#  'Niels Arden Oplev',
#  'Frank Miller',
#  'Marcos Siega',
#  'James Algar',
#  'Menno Meyjes',
#  'David Anspaugh',
#  'André Øvredal',
#  'Mike Disa',
#  'Blake Edwards',
#  'Andrew Bergman',
#  'Barbet Schroeder',
#  'Corey Yuen',
#  'Jacques Perrin',
#  'Paul McGuigan',
#  'Bob Rafelson',
#  'Christian Carion',
#  'John Duigan',
#  'Annabel Jankel',
#  'Jee-woon Kim',
#  'Kent Alterman',
#  'Daniel Algrant',
#  'Lawrence Kasdan',
#  'Peter Webber',
#  'Scott Waugh',
#  'Christian Duguay',
#  'Roger Christian',
#  'John Maybury',
#  'Hugh Johnson',
#  'Rand Ravich',
#  'Asger Leth',
#  'Steve Hickner',
#  'Roger Spottiswoode',
#  'Mary McGuckian',
#  'Diane Keaton',
#  'Robert Towne',
#  'Robert B. Weide',
#  'Gil Kenan',
#  'John Gray',
#  'Danny Pang',
#  'Roman Polanski',
#  'Hark Tsui',
#  'Stefen Fangmeier',
#  'Jonathan Newman',
#  'Josh Trank',
#  'Guillaume Canet',
#  'Rob Minkoff',
#  'Steven Zaillian',
#  'Susan Stroman',
#  'Michael Cristofer',
#  'Michael Caton-Jones',
#  'Demian Lichtenstein',
#  'Ulu Grosbard',
#  'Lexi Alexander',
#  'Henry Selick',
#  'Richard Williams',
#  'Jorge Blanco',
#  'Ron Maxwell',
#  'José Padilha',
#  'Paul Hunter',
#  'Doug Lefler',
#  'Danny DeVito',
#  'Vincent Ward',
#  'Jean-Jacques Annaud',
#  'Marco Schnabel',
#  'Duncan Jones',
#  'Jeb Stuart',
#  'Hoyt Yeatman',
#  'Uwe Boll',
#  'Paul Bolger',
#  'Kerry Conran',
#  'Joseph Ruben',
#  'Bille August',
#  'Charles S. Dutton',
#  'Akiva Schaffer',
#  'Patrick Gilmore',
#  'Wilson Yip',
#  'Jean-Pierre Jeunet',
#  'Walter Hill',
#  'Johnnie To',
#  'Breck Eisner',
#  'Kinka Usher',
#  'Tom Tykwer',
#  'Byron Howard',
#  'Oliver Hirschbiegel',
#  'Elaine May',
#  'Roland Joffé',
#  'Karey Kirkpatrick',
#  'Sergey Bodrov',
#  'Sngmoo Lee',
#  'Marc F. Adler',
#  'Peter Ho-Sun Chan',
#  'Andrey Konchalovskiy',
#  'Ash Brannon',
#  'Peter Ramsey',
#  'Jean-Marie Poiré',
#  'Michael Cimino',
#  'Ron Underwood',
#  'Barry Cook',
#  'Ole Christian Madsen',
#  'Stuart Beattie',
#  'Charles Shyer',
#  'Tony Bill',
#  'Joe Wright',
#  'Des McAnuff',
#  'Mikael Salomon',
#  'Patrick Hughes',
#  'David Soren',
#  'Antony Hoffman',
#  'Sarah Smith',
#  'Wych Kaosayananda',
#  'Yimou Zhang',
#  'Nathan Greno',
#  'Kaige Chen',
#  'Robert Butler',
#  'Pitof',
#  'Will Finn',
#  'Akiva Goldsman',
#  'Daniel Lee',
#  'Cedric Nicolas-Troyan',
#  'Costa-Gavras',
#  'Simon Wells',
#  'Ericson Core',
#  'Wally Pfister',
#  'John Woo',
#  'Jirí Menzel',
#  'Patrice Leconte',
#  'Luc Besson',
#  'Hironobu Sakaguchi',
#  'Carl Rinsch',
#  'Prachya Pinkaew',
#  'Tony Jaa',
#  'Karan Johar',
#  'Chatrichalerm Yukol',
#  'Hayao Miyazaki',
#  'Carlos Saura',
#  'Takao Okawara',
#  'Chan-wook Park',
#  'Katsuhiro Ôtomo',
#  'Lajos Koltai',
#  'Joon-ho Bong']

# %%
actor_1_high = list(actor_1.loc[actor_1["profit"] > 0]["actor_1_name"])

# %%
actor_1_low = list(actor_1.loc[actor_1["profit"] <- 0]["actor_1_name"])

# %%
actor_2_high = list(actor_2.loc[actor_2["profit"] > 0]["actor_2_name"])

# %%
actor_2_low = list(actor_2.loc[actor_2["profit"] <- 0]["actor_2_name"])

# %%
actor_3_high = list(actor_3.loc[actor_3["profit"] > 0]["actor_3_name"])

# %%
actor_3_low = list(actor_3.loc[actor_3["profit"] <- 0]["actor_3_name"])

# %%
df["director_high"] = [1 if director_high.count(x) > 0 else 0 for x in df["director_name"]]
df["director_low"] = [1 if director_low.count(x) > 0 else 0 for x in df["director_name"]]

# %%
df["actor_1_high"] = [1 if actor_1_high.count(x) > 0 else 0 for x in df["actor_1_name"]]
df["actor_1_low"] = [1 if actor_1_low.count(x) > 0 else 0 for x in df["actor_1_name"]]

# %%
df["actor_2_high"] = [1 if actor_2_high.count(x) > 0 else 0 for x in df["actor_2_name"]]
df["actor_2_low"] = [1 if actor_2_low.count(x) > 0 else 0 for x in df["actor_2_name"]]

# %%
df["actor_3_high"] = [1 if actor_3_high.count(x) > 0 else 0 for x in df["actor_3_name"]]
df["actor_3_low"] = [1 if actor_3_low.count(x) > 0 else 0 for x in df["actor_3_name"]]

# %%
df_actors = df.copy()

# %%
team_train_X = pd.read_csv('train.csv')
team_test_X = pd.read_csv('test.csv')

# %% [markdown]
# ## Investigating number of names that came up more than once

# %%
#code showing the ratio of actor names that show up more than once


df = pd.read_csv('cleaned_data.csv')

director = sum(df["director_name"].value_counts() > 1) /len(df["director_name"])
actor_1 = sum(df["actor_1_name"].value_counts() > 1) /len(df["actor_1_name"])
actor_2 = sum(df["actor_2_name"].value_counts() > 1) /len(df["actor_2_name"])
actor_3 = sum(df["actor_3_name"].value_counts() > 1) /len(df["actor_3_name"])

print("Director Ration:", director, "Actor 1 Ratio:", actor_1, "Actor 2 Ratio:", actor_2, "Actor 3 Ratio:", actor_3)
# Out:
# Director Ration: 0.19084375831780676 Actor 1 Ratio: 0.1485227575192973 Actor 2 Ratio: 0.19377162629757785 Actor 3 Ratio: 0.18658504125632153

# %% [markdown]
# This ratio is very small - this could be a problem!
