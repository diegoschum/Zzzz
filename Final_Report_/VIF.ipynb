# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error



from sklearn.feature_selection import RFE
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('cleaned_data.csv')
df.columns
# Out:
# Index(['director_name', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes',
#        'gross', 'actor_1_name', 'movie_title', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'language', 'country', 'content_rating', 'budget',
#        'title_year', 'actor_2_facebook_likes', 'aspect_ratio', 'profit',
#        'gross_bin', 'action', 'adventure', 'animation', 'biography', 'comedy',
#        'crime', 'documentary', 'drama', 'family', 'fantasy', 'film-noir',
#        'history', 'horror', 'music', 'musical', 'mystery', 'romance', 'sci_fi',
#        'sport', 'thriller', 'war', 'western', 'director_high', 'director_low',
#        'actor_1_high', 'actor_1_low', 'actor_2_high', 'actor_2_low',
#        'actor_3_high', 'actor_3_low', 'is_english', 'profit_binary'],
#       dtype='object')

# %%
X = df[['duration',
       'director_facebook_likes', 'actor_3_facebook_likes',
       'actor_1_facebook_likes', 'cast_total_facebook_likes',
       'facenumber_in_poster', 'title_year', 'actor_2_facebook_likes',
       'aspect_ratio', 'profit']]

# %%
#looking at VIF 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
# Out:
#                       feature           VIF
# 0                       const  45633.468439
# 1                    duration      1.112283
# 2     director_facebook_likes      1.054721
# 3      actor_3_facebook_likes      8.363941
# 4      actor_1_facebook_likes    201.815449
# 5   cast_total_facebook_likes    304.323437
# 6        facenumber_in_poster      1.020413
# 7                  title_year      1.117374
# 8      actor_2_facebook_likes     19.341341
# 9                aspect_ratio      1.088387
# 10                     profit      1.007980

# %% [markdown]
# There is high VIF values for actor_1_facebook_likes, actor_1_facebook_likes, actor_2_facebook_likes.

# %% [markdown]
# ## Looking at correlation table:

# %%
X.corr()
# Out:
#                            const  duration  director_facebook_likes  \
# const                        NaN       NaN                      NaN
# duration                     NaN  1.000000                 0.180659
# director_facebook_likes      NaN  0.180659                 1.000000
# actor_3_facebook_likes       NaN  0.125808                 0.117414
# actor_1_facebook_likes       NaN  0.083661                 0.089655
# cast_total_facebook_likes    NaN  0.120210                 0.118573
# facenumber_in_poster         NaN  0.026967                -0.048020
# title_year                   NaN -0.130258                -0.044704
# actor_2_facebook_likes       NaN  0.128955                 0.116076
# aspect_ratio                 NaN  0.152966                 0.037482
# profit                       NaN  0.008300                 0.024458
#
#                            actor_3_facebook_likes  actor_1_facebook_likes  \
# const                                         NaN                     NaN
# duration                                 0.125808                0.083661
# director_facebook_likes                  0.117414                0.089655
# actor_3_facebook_likes                   1.000000                0.252420
# actor_1_facebook_likes                   0.252420                1.000000
# cast_total_facebook_likes                0.489800                0.944816
# facenumber_in_poster                     0.106213                0.057460
# title_year                               0.117428                0.096089
# actor_2_facebook_likes                   0.553760                0.391188
# aspect_ratio                             0.046322                0.056862
# profit                                   0.052425                0.027909
#
#                            cast_total_facebook_likes  facenumber_in_poster  \
# const                                            NaN                   NaN
# duration                                    0.120210              0.026967
# director_facebook_likes                     0.118573             -0.048020
# actor_3_facebook_likes                      0.489800              0.106213
# actor_1_facebook_likes                      0.944816              0.057460
# cast_total_facebook_likes                   1.000000              0.080765
# facenumber_in_poster                        0.080765              1.000000
# title_year                                  0.126927              0.069937
# actor_2_facebook_likes                      0.643003              0.073149
# aspect_ratio                                0.068860              0.018864
# profit                                      0.043866              0.011518
#
#                            title_year  actor_2_facebook_likes  aspect_ratio  \
# const                             NaN                     NaN           NaN
# duration                    -0.130258                0.128955      0.152966
# director_facebook_likes     -0.044704                0.116076      0.037482
# actor_3_facebook_likes       0.117428                0.553760      0.046322
# actor_1_facebook_likes       0.096089                0.391188      0.056862
# cast_total_facebook_likes    0.126927                0.643003      0.068860
# facenumber_in_poster         0.069937                0.073149      0.018864
# title_year                   1.000000                0.122330      0.216728
# actor_2_facebook_likes       0.122330                1.000000      0.063890
# aspect_ratio                 0.216728                0.063890      1.000000
# profit                      -0.029582                0.042224     -0.005286
#
#                              profit
# const                           NaN
# duration                   0.008300
# director_facebook_likes    0.024458
# actor_3_facebook_likes     0.052425
# actor_1_facebook_likes     0.027909
# cast_total_facebook_likes  0.043866
# facenumber_in_poster       0.011518
# title_year                -0.029582
# actor_2_facebook_likes     0.042224
# aspect_ratio              -0.005286
# profit                     1.000000

# %% [markdown]
# There is a high correlation between actor_1_facebook_likes and cast_total_facebook_likes (0.94), as well as cast_total_facebook_likes and actor_2_facebook_likes (0.64). We shall regulize the model using Ridge or Lasso to take this into account.

# %%
train = pd.read_csv('train.csv')

# %%
train.columns
# Out:
# Index(['director_name', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes',
#        'gross', 'genres', 'actor_1_name', 'movie_title',
#        'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'aspect_ratio', 'profit', 'gross_bin', 'action', 'adventure',
#        'animation', 'biography', 'comedy', 'crime', 'documentary', 'drama',
#        'family', 'fantasy', 'film-noir', 'history', 'horror', 'music',
#        'musical', 'mystery', 'romance', 'sci_fi', 'sport', 'thriller', 'war',
#        'western', 'director_high', 'director_low', 'actor_1_high',
#        'actor_1_low', 'actor_2_high', 'actor_2_low', 'actor_3_high',
#        'actor_3_low', 'is_english', 'profit_binary'],
#       dtype='object')

# %%
X = df[[ 'duration', 'director_facebook_likes',
       'actor_3_facebook_likes',  'actor_1_facebook_likes',
       'cast_total_facebook_likes',  'facenumber_in_poster',
       'actor_2_facebook_likes',
       'aspect_ratio', 'action', 'adventure',
       'animation', 'biography', 'comedy', 'crime', 'documentary', 'drama',
       'family', 'fantasy', 'film-noir', 'history', 'horror', 'music',
       'musical', 'mystery', 'romance', 'sci_fi', 'sport', 'thriller', 'war',
       'western', 'director_high', 'director_low', 'actor_1_high',
       'actor_1_low', 'actor_2_high', 'actor_2_low', 'actor_3_high',
       'actor_3_low', 'is_english', 'profit_binary']]

# %%
#looking at VIF 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
print(vif_data.loc[vif_data.VIF > 15])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                       feature         VIF
# 0                       const    0.000000
# 1                    duration    1.465983
# 2     director_facebook_likes    1.069819
# 3      actor_3_facebook_likes    8.629599
# 4      actor_1_facebook_likes  209.638774
# 5   cast_total_facebook_likes  316.703639
# 6        facenumber_in_poster    1.106950
# 7      actor_2_facebook_likes   20.008131
# 8                aspect_ratio    1.092236
# 9                      action    1.604189
# 10                  adventure    1.595073
# 11                  animation    1.599686
# 12                  biography    1.260675
# 13                     comedy    1.784374
# 14                      crime    1.367508
# 15                documentary    1.086076
# 16                      drama    1.690636
# 17                     family    1.808023
# 18                    fantasy    1.262247
# 19                  film-noir    1.006198
# 20                    history    1.321349
# 21                     horror    1.439738
# 22                      music    1.056905
# 23                    musical    1.069301
# 24                    mystery    1.190194
# 25                    romance    1.206416
# 26                     sci_fi    1.262826
# 27                      sport    1.090826
# 28                   thriller    1.707969
# 29                        war    1.209049
# 30                    western    1.030769
# 31              director_high         inf
# 32               director_low         inf
# 33               actor_1_high         inf
# 34                actor_1_low         inf
# 35               actor_2_high         inf
# 36                actor_2_low         inf
# 37               actor_3_high         inf
# 38                actor_3_low         inf
# 39                 is_english    1.111310
# 40              profit_binary    2.398120
#                       feature         VIF
# 4      actor_1_facebook_likes  209.638774
# 5   cast_total_facebook_likes  316.703639
# 7      actor_2_facebook_likes   20.008131
# 31              director_high         inf
# 32               director_low         inf
# 33               actor_1_high         inf
# 34                actor_1_low         inf
# 35               actor_2_high         inf
# 36                actor_2_low         inf
# 37               actor_3_high         inf
# 38                actor_3_low         inf
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
# 31              director_high         inf
#
# 32               director_low         inf
#
# 33               actor_1_high         inf
#
# 34                actor_1_low         inf
#
# 35               actor_2_high         inf
#
# 36                actor_2_low         inf
#
# 37               actor_3_high         inf
#
# 38                actor_3_low         inf
#
# ## This indicates that there is very high multicolinearity amoung the data. This might be due to the fact that there is high correlation between high and low variables. In order to take this into account, I eliminated the low variables:
#
# 4      actor_1_facebook_likes  209.600412
#
# 5   cast_total_facebook_likes  316.586311
#
# 7      actor_2_facebook_likes   20.004890

# %%
X = df[[ 'duration', 'director_facebook_likes',
       'actor_3_facebook_likes',  'actor_1_facebook_likes',
       'cast_total_facebook_likes',  'facenumber_in_poster',
       'actor_2_facebook_likes',
       'aspect_ratio', 'action', 'adventure',
       'animation', 'biography', 'comedy', 'crime', 'documentary', 'drama',
       'family', 'fantasy', 'film-noir', 'history', 'horror', 'music',
       'musical', 'mystery', 'romance', 'sci_fi', 'sport', 'thriller', 'war',
       'western', 'director_high',  'actor_1_high',
        'actor_2_high', 'actor_3_high',
        'is_english', 'profit_binary']]

# %%
#looking at VIF 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
# Out:
#                       feature         VIF
# 0                       const   99.425530
# 1                    duration    1.465983
# 2     director_facebook_likes    1.069819
# 3      actor_3_facebook_likes    8.629599
# 4      actor_1_facebook_likes  209.638774
# 5   cast_total_facebook_likes  316.703639
# 6        facenumber_in_poster    1.106950
# 7      actor_2_facebook_likes   20.008131
# 8                aspect_ratio    1.092236
# 9                      action    1.604189
# 10                  adventure    1.595073
# 11                  animation    1.599686
# 12                  biography    1.260675
# 13                     comedy    1.784374
# 14                      crime    1.367508
# 15                documentary    1.086076
# 16                      drama    1.690636
# 17                     family    1.808023
# 18                    fantasy    1.262247
# 19                  film-noir    1.006198
# 20                    history    1.321349
# 21                     horror    1.439738
# 22                      music    1.056905
# 23                    musical    1.069301
# 24                    mystery    1.190194
# 25                    romance    1.206416
# 26                     sci_fi    1.262826
# 27                      sport    1.090826
# 28                   thriller    1.707969
# 29                        war    1.209049
# 30                    western    1.030769
# 31              director_high    1.458230
# 32               actor_1_high    1.423429
# 33               actor_2_high    1.732775
# 34               actor_3_high    2.075247
# 35                 is_english    1.111310
# 36              profit_binary    2.398120

# %% [markdown]
# 31              director_high    1.451423
#
# 32               actor_1_high    1.420830
#
# 33               actor_2_high    1.736591
#
# 34               actor_3_high    2.079257
#
# ## We can now see that there is less multicolinearity amongst the cast variables. We shall now use this variables in our model to see if this fixes the previous issues.
