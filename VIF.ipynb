# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error



from sklearn.feature_selection import RFE
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('cleaned_data.csv')
df.columns
# Out:
# Index(['director_name', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes',
#        'gross', 'actor_1_name', 'movie_title', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'language', 'country', 'content_rating', 'budget',
#        'title_year', 'actor_2_facebook_likes', 'aspect_ratio', 'profit',
#        'gross_bin', 'action', 'adventure', 'animation', 'biography', 'comedy',
#        'crime', 'documentary', 'drama', 'family', 'fantasy', 'film-noir',
#        'history', 'horror', 'music', 'musical', 'mystery', 'romance', 'sci_fi',
#        'sport', 'thriller', 'war', 'western', 'director_high', 'director_low',
#        'actor_1_high', 'actor_1_low', 'actor_2_high', 'actor_2_low',
#        'actor_3_high', 'actor_3_low', 'is_english', 'profit_binary'],
#       dtype='object')

# %%
X = df[['duration',
       'director_facebook_likes', 'actor_3_facebook_likes',
       'actor_1_facebook_likes', 'cast_total_facebook_likes',
       'facenumber_in_poster', 'title_year', 'actor_2_facebook_likes',
       'aspect_ratio', 'profit']]

# %%
#looking at VIF 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
# Out:
#                       feature           VIF
# 0                       const  46228.792712
# 1                    duration      1.112963
# 2     director_facebook_likes      1.059676
# 3      actor_3_facebook_likes      8.436235
# 4      actor_1_facebook_likes    207.038770
# 5   cast_total_facebook_likes    312.230193
# 6        facenumber_in_poster      1.021622
# 7                  title_year      1.133140
# 8      actor_2_facebook_likes     19.744161
# 9                aspect_ratio      1.090800
# 10                     profit      1.094960

# %% [markdown]
# There is high VIF values for actor_1_facebook_likes, actor_1_facebook_likes, actor_2_facebook_likes.

# %% [markdown]
# ## Looking at correlation table:

# %%
X.corr()
# Out:
#                            const  duration  director_facebook_likes  \
# const                        NaN       NaN                      NaN
# duration                     NaN  1.000000                 0.180935
# director_facebook_likes      NaN  0.180935                 1.000000
# actor_3_facebook_likes       NaN  0.126184                 0.117329
# actor_1_facebook_likes       NaN  0.084123                 0.089717
# cast_total_facebook_likes    NaN  0.120861                 0.118631
# facenumber_in_poster         NaN  0.027091                -0.047899
# title_year                   NaN -0.130560                -0.044568
# actor_2_facebook_likes       NaN  0.129689                 0.116076
# aspect_ratio                 NaN  0.152889                 0.037902
# profit                       NaN  0.071213                 0.102291
#
#                            actor_3_facebook_likes  actor_1_facebook_likes  \
# const                                         NaN                     NaN
# duration                                 0.126184                0.084123
# director_facebook_likes                  0.117329                0.089717
# actor_3_facebook_likes                   1.000000                0.252165
# actor_1_facebook_likes                   0.252165                1.000000
# cast_total_facebook_likes                0.489614                0.944793
# facenumber_in_poster                     0.105984                0.057065
# title_year                               0.117313                0.095866
# actor_2_facebook_likes                   0.553635                0.390949
# aspect_ratio                             0.046303                0.056757
# profit                                   0.174435                0.057217
#
#                            cast_total_facebook_likes  facenumber_in_poster  \
# const                                            NaN                   NaN
# duration                                    0.120861              0.027091
# director_facebook_likes                     0.118631             -0.047899
# actor_3_facebook_likes                      0.489614              0.105984
# actor_1_facebook_likes                      0.944793              0.057065
# cast_total_facebook_likes                   1.000000              0.080325
# facenumber_in_poster                        0.080325              1.000000
# title_year                                  0.126692              0.069762
# actor_2_facebook_likes                      0.642853              0.072864
# aspect_ratio                                0.068771              0.018824
# profit                                      0.112756             -0.026529
#
#                            title_year  actor_2_facebook_likes  aspect_ratio  \
# const                             NaN                     NaN           NaN
# duration                    -0.130560                0.129689      0.152889
# director_facebook_likes     -0.044568                0.116076      0.037902
# actor_3_facebook_likes       0.117313                0.553635      0.046303
# actor_1_facebook_likes       0.095866                0.390949      0.056757
# cast_total_facebook_likes    0.126692                0.642853      0.068771
# facenumber_in_poster         0.069762                0.072864      0.018824
# title_year                   1.000000                0.122183      0.216508
# actor_2_facebook_likes       0.122183                1.000000      0.063894
# aspect_ratio                 0.216508                0.063894      1.000000
# profit                      -0.115179                0.127142     -0.059317
#
#                              profit
# const                           NaN
# duration                   0.071213
# director_facebook_likes    0.102291
# actor_3_facebook_likes     0.174435
# actor_1_facebook_likes     0.057217
# cast_total_facebook_likes  0.112756
# facenumber_in_poster      -0.026529
# title_year                -0.115179
# actor_2_facebook_likes     0.127142
# aspect_ratio              -0.059317
# profit                     1.000000

# %% [markdown]
# There is a high correlation between actor_1_facebook_likes and cast_total_facebook_likes (0.94), as well as cast_total_facebook_likes and actor_2_facebook_likes (0.64). We shall regulize the model using Ridge or Lasso to take this into account.

# %%
train = pd.read_csv('train.csv')

# %%
train.columns
# Out:
# Index(['director_name', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes',
#        'gross', 'genres', 'actor_1_name', 'movie_title',
#        'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'aspect_ratio', 'profit', 'gross_bin', 'action', 'adventure',
#        'animation', 'biography', 'comedy', 'crime', 'documentary', 'drama',
#        'family', 'fantasy', 'film-noir', 'history', 'horror', 'music',
#        'musical', 'mystery', 'romance', 'sci_fi', 'sport', 'thriller', 'war',
#        'western', 'director_high', 'director_low', 'actor_1_high',
#        'actor_1_low', 'actor_2_high', 'actor_2_low', 'actor_3_high',
#        'actor_3_low', 'is_english', 'profit_binary'],
#       dtype='object')

# %%
X = df[[ 'duration', 'director_facebook_likes',
       'actor_3_facebook_likes',  'actor_1_facebook_likes',
       'cast_total_facebook_likes',  'facenumber_in_poster',
       'actor_2_facebook_likes',
       'aspect_ratio', 'action', 'adventure',
       'animation', 'biography', 'comedy', 'crime', 'documentary', 'drama',
       'family', 'fantasy', 'film-noir', 'history', 'horror', 'music',
       'musical', 'mystery', 'romance', 'sci_fi', 'sport', 'thriller', 'war',
       'western', 'director_high', 'director_low', 'actor_1_high',
       'actor_1_low', 'actor_2_high', 'actor_2_low', 'actor_3_high',
       'actor_3_low', 'is_english', 'profit_binary']]

# %%
#looking at VIF 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
print(vif_data.loc[vif_data.VIF > 15])
# Out:
# C:\Users\Yasmeen\AppData\Roaming\Python\Python310\site-packages\statsmodels\regression\linear_model.py:1752: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\Yasmeen\AppData\Roaming\Python\Python310\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                       feature         VIF
# 0                       const    0.000000
# 1                    duration    1.469866
# 2     director_facebook_likes    1.069845
# 3      actor_3_facebook_likes    8.629169
# 4      actor_1_facebook_likes  209.600412
# 5   cast_total_facebook_likes  316.586311
# 6        facenumber_in_poster    1.106666
# 7      actor_2_facebook_likes   20.004890
# 8                aspect_ratio    1.092222
# 9                      action    1.602375
# 10                  adventure    1.595014
# 11                  animation    1.605578
# 12                  biography    1.260912
# 13                     comedy    1.788665
# 14                      crime    1.368476
# 15                documentary    1.086365
# 16                      drama    1.693902
# 17                     family    1.814367
# 18                    fantasy    1.262095
# 19                  film-noir    1.006200
# 20                    history    1.323985
# 21                     horror    1.443268
# 22                      music    1.057074
# 23                    musical    1.070531
# 24                    mystery    1.190675
# 25                    romance    1.206901
# 26                     sci_fi    1.260835
# 27                      sport    1.090971
# 28                   thriller    1.709335
# 29                        war    1.209982
# 30                    western    1.031446
# 31              director_high         inf
# 32               director_low         inf
# 33               actor_1_high         inf
# 34                actor_1_low         inf
# 35               actor_2_high         inf
# 36                actor_2_low         inf
# 37               actor_3_high         inf
# 38                actor_3_low         inf
# 39                 is_english    1.104769
# 40              profit_binary    2.379055
#                       feature         VIF
# 4      actor_1_facebook_likes  209.600412
# 5   cast_total_facebook_likes  316.586311
# 7      actor_2_facebook_likes   20.004890
# 31              director_high         inf
# 32               director_low         inf
# 33               actor_1_high         inf
# 34                actor_1_low         inf
# 35               actor_2_high         inf
# 36                actor_2_low         inf
# 37               actor_3_high         inf
# 38                actor_3_low         inf

# %% [markdown]
# 31              director_high         inf
#
# 32               director_low         inf
#
# 33               actor_1_high         inf
#
# 34                actor_1_low         inf
#
# 35               actor_2_high         inf
#
# 36                actor_2_low         inf
#
# 37               actor_3_high         inf
#
# 38                actor_3_low         inf
#
# ## This indicates that there is very high multicolinearity amoung the data. This might be due to the fact that there is high correlation between high and low variables. In order to take this into account, I eliminated the low variables:
#
# 4      actor_1_facebook_likes  209.600412
#
# 5   cast_total_facebook_likes  316.586311
#
# 7      actor_2_facebook_likes   20.004890

# %%
X = df[[ 'duration', 'director_facebook_likes',
       'actor_3_facebook_likes',  'actor_1_facebook_likes',
       'cast_total_facebook_likes',  'facenumber_in_poster',
       'actor_2_facebook_likes',
       'aspect_ratio', 'action', 'adventure',
       'animation', 'biography', 'comedy', 'crime', 'documentary', 'drama',
       'family', 'fantasy', 'film-noir', 'history', 'horror', 'music',
       'musical', 'mystery', 'romance', 'sci_fi', 'sport', 'thriller', 'war',
       'western', 'director_high',  'actor_1_high',
        'actor_2_high', 'actor_3_high',
        'is_english', 'profit_binary']]

# %%
#looking at VIF 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
# Out:
#                       feature         VIF
# 0                       const  100.426246
# 1                    duration    1.469866
# 2     director_facebook_likes    1.069845
# 3      actor_3_facebook_likes    8.629169
# 4      actor_1_facebook_likes  209.600412
# 5   cast_total_facebook_likes  316.586311
# 6        facenumber_in_poster    1.106666
# 7      actor_2_facebook_likes   20.004890
# 8                aspect_ratio    1.092222
# 9                      action    1.602375
# 10                  adventure    1.595014
# 11                  animation    1.605578
# 12                  biography    1.260912
# 13                     comedy    1.788665
# 14                      crime    1.368476
# 15                documentary    1.086365
# 16                      drama    1.693902
# 17                     family    1.814367
# 18                    fantasy    1.262095
# 19                  film-noir    1.006200
# 20                    history    1.323985
# 21                     horror    1.443268
# 22                      music    1.057074
# 23                    musical    1.070531
# 24                    mystery    1.190675
# 25                    romance    1.206901
# 26                     sci_fi    1.260835
# 27                      sport    1.090971
# 28                   thriller    1.709335
# 29                        war    1.209982
# 30                    western    1.031446
# 31              director_high    1.451423
# 32               actor_1_high    1.420830
# 33               actor_2_high    1.736591
# 34               actor_3_high    2.079257
# 35                 is_english    1.104769
# 36              profit_binary    2.379055

# %% [markdown]
# 31              director_high    1.451423
#
# 32               actor_1_high    1.420830
#
# 33               actor_2_high    1.736591
#
# 34               actor_3_high    2.079257
#
# ## We can now see that there is less multicolinearity amongst the cast variables. We shall now use this variables in our model to see if this fixes the previous issues.
