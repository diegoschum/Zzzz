# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import statsmodels.formula.api as smf

# %%
df = pd.read_csv('movie_metadata.csv')

# %%
#Plot revenue by genre
df['genres'] = df['genres'].str.split('|')
df = df.explode('genres')
df['genres'] = df['genres'].str.strip()
df['genres'] = df['genres'].str.lower()
df['genres'] = df['genres'].str.replace(' ','_')
df['genres'] = df['genres'].str.replace('-','_')
df['genres'] = df['genres'].str.replace('&','_')

df['genres'].value_counts().plot(kind='bar', figsize=(20,10))
plt.title('Number of movies by genre')
plt.xlabel('Genre')
plt.ylabel('Number of movies')
plt.show()

# %%
#gross revenue by genre
df.groupby('genres')['gross'].mean().plot(kind='bar', figsize=(20,10))
plt.title('Average gross revenue by genre')
plt.xlabel('Genre')
plt.ylabel('Average gross revenue')
plt.show()

# %%
#remove rows having genres with combiend revenue = 0 (film_noir,,game_shwo, reality_tv)

df = df[df['genres'] != 'film_noir']
df = df[df['genres'] != 'game_show']
df = df[df['genres'] != 'reality_tv']

df['profit'] = df['gross'] - df['budget']
profit_by_genre = df.groupby('genres')['profit'].mean()
gross_by_genre = df.groupby('genres')['gross'].mean()

# Define the colors for the bars
colors = sns.color_palette('Set2', n_colors=2)

# Create a barplot of the average profit by genre
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(20,10))
sns.barplot(x=profit_by_genre.index, y=profit_by_genre.values, color=colors[0], alpha=0.5, label='Average profit', ax=ax)

# Overlay a barplot of the average gross revenue by genre
sns.barplot(x=gross_by_genre.index, y=gross_by_genre.values, color=colors[1], alpha=0.5, label='Average gross revenue', ax=ax)

# Set the title, x-label, and y-label
ax.set_title('Average profit and gross revenue by genre')
ax.set_xlabel('Genre')
ax.set_ylabel('Amount')

# Add a legend
ax.legend(loc='best')

# Show the plot
plt.show()

# %%
#histogram of gross revenue
plt.hist(df['gross'])
# Out:
# (array([9.472e+03, 1.692e+03, 6.030e+02, 2.150e+02, 1.280e+02, 5.700e+01,
#         1.100e+01, 4.000e+00, 1.200e+01, 4.000e+00]),
#  array([1.62000000e+02, 7.60507305e+07, 1.52101299e+08, 2.28151868e+08,
#         3.04202436e+08, 3.80253004e+08, 4.56303573e+08, 5.32354142e+08,
#         6.08404710e+08, 6.84455278e+08, 7.60505847e+08]),
#  <BarContainer object of 10 artists>)

# %%
# #log transform the gross revenue
# df['gross'] = np.log(df['gross'])
# #now plot the histogram of the log transformed gross revenue
# plt.hist(df['gross'])

# %%
missing_values_count = df.isnull().sum()
print(missing_values_count)
# Out:
# color                          52
# director_name                 307
# num_critic_for_reviews         94
# duration                       34
# director_facebook_likes       307
# actor_3_facebook_likes         44
# actor_2_name                   23
# actor_1_facebook_likes         10
# gross                        2297
# genres                          0
# actor_1_name                   10
# movie_title                     0
# num_voted_users                 0
# cast_total_facebook_likes       0
# actor_3_name                   44
# facenumber_in_poster           31
# plot_keywords                 310
# movie_imdb_link                 0
# num_user_for_reviews           42
# language                       31
# country                        11
# content_rating                707
# budget                       1256
# title_year                    314
# actor_2_facebook_likes         23
# imdb_score                      0
# aspect_ratio                  728
# movie_facebook_likes            0
# profit                       2954
# dtype: int64

# %%
df = df.drop(columns=['color'])
n_original = len(df)
df.dropna(inplace=True)
n_null_removed = len(df)
print("original size, new size: "+ str(n_original)+", " +str(n_null_removed))
# Out:
# original size, new size: 14495, 11237

# %%
df.head()
# Out:
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 0   James Cameron                   723.0     178.0                      0.0
# 0   James Cameron                   723.0     178.0                      0.0
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 0                   855.0  Joel David Moore                  1000.0
# 0                   855.0  Joel David Moore                  1000.0
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
#
#          gross     genres actor_1_name  ... language  country  content_rating  \
# 0  760505847.0     action  CCH Pounder  ...  English      USA           PG-13
# 0  760505847.0  adventure  CCH Pounder  ...  English      USA           PG-13
# 0  760505847.0    fantasy  CCH Pounder  ...  English      USA           PG-13
# 0  760505847.0     sci_fi  CCH Pounder  ...  English      USA           PG-13
# 1  309404152.0     action  Johnny Depp  ...  English      USA           PG-13
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
#
#   movie_facebook_likes       profit
# 0                33000  523505847.0
# 0                33000  523505847.0
# 0                33000  523505847.0
# 0                33000  523505847.0
# 1                    0    9404152.0
#
# [5 rows x 28 columns]

# %%
# select the numerical columns of interest
numerical_cols = ['num_critic_for_reviews', 'duration', 'director_facebook_likes', 'actor_3_facebook_likes', 
                  'actor_1_facebook_likes', 'gross', 'num_voted_users', 'cast_total_facebook_likes', 
                  'facenumber_in_poster', 'num_user_for_reviews', 'budget', 'title_year', 'actor_2_facebook_likes',
                  'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'profit']

# create a histogram for each numerical column
for col in numerical_cols:
    plt.hist(df[col], bins=20)
    plt.title(col)
    plt.show()
    
# create a boxplot for each numerical column
for col in numerical_cols:
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()
    
# create a correlation heatmap to see the pairwise correlation between numerical variables
corr = df[numerical_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
#outlier dist of profit
sns.boxplot(x=df['profit'])
plt.show()

# %%
#outlier analysis of profit
len(df)
# Out:
# 11237

# %%
#remove outliers of profit within 3 standard deviations
df = df[df['profit'] < 3*df['profit'].std()]
df = df[df['profit'] > -3*df['profit'].std()]
len(df)
# Out:
# 11211

# %%
11211/ 11237
# Out:
# 0.9976862151819881

# %%
#outlier dist of profit
sns.boxplot(x=df['profit'])
plt.show()

# %%
#distribution of profit, log transform the profit
df['log_profit'] = np.log(df['profit'])
#now plot the histogram of the log transformed profit
plt.hist(df['log_profit'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (array([   7.,   16.,   54.,  109.,  246.,  639., 1330., 2105., 1151.,
#          264.]),
#  array([ 8.87738195,  9.99724963, 11.11711732, 12.236985  , 13.35685268,
#         14.47672036, 15.59658804, 16.71645572, 17.8363234 , 18.95619108,
#         20.07605876]),
#  <BarContainer object of 10 artists>)

# %%
 #export df as is, rename as cleaned_data
 df.to_csv('cleaned_data.csv', index=False)

# %%
# create binary variables for each genre
genres_df = df['genres'].str.get_dummies(sep='|')
# merge new dataframe with original dataframe
df = pd.concat([df, genres_df], axis=1)

# %%
#export df as is, rename as cleaned_data
df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# Model 1: Predicting Gross Revenue

# %%
df.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'profit',
#        'log_profit', 'action', 'adventure', 'animation', 'biography', 'comedy',
#        'crime', 'documentary', 'drama', 'family', 'fantasy', 'history',
#        'horror', 'music', 'musical', 'mystery', 'romance', 'sci_fi', 'sport',
#        'thriller', 'war', 'western'],
#       dtype='object')

# %%
#make traing and test sets to predict gross revenue and profit in varying models

df.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'profit',
#        'log_profit', 'action', 'adventure', 'animation', 'biography', 'comedy',
#        'crime', 'documentary', 'drama', 'family', 'fantasy', 'history',
#        'horror', 'music', 'musical', 'mystery', 'romance', 'sci_fi', 'sport',
#        'thriller', 'war', 'western'],
#       dtype='object')

# %%
#multicoliniarity
correlation_matrix = df[['action', 'adventure', 'animation', 'biography', 'comedy', 'crime', 'documentary', 'drama', 'family', 'fantasy', 'history', 'horror', 'music', 'musical', 'mystery', 'romance', 'sci_fi', 'sport', 'thriller', 'war', 'western']].corr()
sns.heatmap(correlation_matrix)
# Out:
# <AxesSubplot:>

# %%
# Split the data into training and testing sets
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Save the training and testing data as CSV files
train_data.to_csv('train.csv', index=False)
test_data.to_csv('test.csv', index=False)

# %%
# Create a linear regression model, using smf 
model = smf.ols(formula='gross ~ action + adventure + animation + biography + comedy + crime + documentary + drama + family + fantasy + history + horror + music + musical + mystery + romance + sci_fi + sport + thriller + war + western', data=train_data)

# Fit the model to the training data
model = model.fit()

# Print the model summary

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  gross   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     42.87
# Date:                Sun, 05 Mar 2023   Prob (F-statistic):          9.14e-161
# Time:                        20:35:26   Log-Likelihood:            -1.7517e+05
# No. Observations:                8989   AIC:                         3.504e+05
# Df Residuals:                    8968   BIC:                         3.505e+05
# Df Model:                          20
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    1.127e+20   1.47e+20      0.765      0.444   -1.76e+20    4.02e+20
# action      -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# adventure   -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# animation   -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# biography   -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# comedy      -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# crime       -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# documentary -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# drama       -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# family      -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# fantasy     -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# history     -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# horror      -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# music       -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# musical     -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# mystery     -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# romance     -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# sci_fi      -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# sport       -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# thriller    -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# war         -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# western     -1.127e+20   1.47e+20     -0.765      0.444   -4.02e+20    1.76e+20
# ==============================================================================
# Omnibus:                     5131.492   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54239.565
# Skew:                           2.573   Prob(JB):                         0.00
# Kurtosis:                      13.878   Cond. No.                     9.71e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.04e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
